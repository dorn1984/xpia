# %%
import pandas as pd
# %matplotlib inline

# %%
zifile = "/glade/scratch/doubrawa/postProcessing/LES_25m_zi_10x10_2015_03_28.csv"

# %%
df = pd.read_csv(zifile,header=None,index_col=[0])

# %%
zifile = "/glade/scratch/doubrawa/postProcessing/LES_25m_zi_10x10_2015_03_21.csv"

# %%
df2 = pd.read_csv(zifile,header=None,index_col=[0])

# %%
df.plot()
df2.plot()
