# %% [markdown]
# # packages

# %%
import numpy as np
import pandas as pd
import xarray
import funcs as f
import os

# %%
from scipy.interpolate import RectBivariateSpline

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
fs=14
plt.rc("font",size=fs)

# %% [markdown]
# ### parameters

# %%
spacings = {"mynn":333, "ysu":333, "sh":333, "vles":333, "LES":25, "LES_raw":25}

# %%
colors = { "LES"   :"k",
          "LES_raw":"k",
          "vles"   :"#808B96",
          "mynn"   :"#641E16",
          "ysu"    :"#A93226",
          "sh"     :"#D98880",}

lss =    { "LES"   :"-",
          "LES_raw":"-",
          "vles"   :"-",
          "mynn"   :"-",
          "ysu"    :"-",
          "sh"     :"-",}

lws =    { "LES"   :2,
          "LES_raw":4,
          "vles"   :2,
          "mynn"   :2,
          "ysu"    :2,
          "sh"     :2}

# %%
keys_in_order = ['LES_raw', 'LES', 'vles', 'mynn', 'ysu', 'sh']
sims          = ["LES","vles","mynn","ysu","sh"]
datapath      = "/Volumes/Baby-Orange/XPIA-NCAR/rawest/"
outpath       = "/Volumes/Baby-Orange/XPIA-NCAR/processed/"

# %% [markdown]
# ### io

# %%
df_zi       = pd.read_csv("/Volumes/Baby-Orange/XPIA-NCAR/processed/ziL_all_days.csv", header=None, index_col=[0], parse_dates=True)
z_zi_target = 0.5

# %%
convective      = pd.read_csv(os.path.join(outpath,"datetimes_ziL_gt_25.csv"),header=None,index_col=[0])
convective_list = np.array([ pd.Timestamp(l[0]) for l in convective.values.tolist() ])
nt              = len(convective_list)
print(nt)
# Out:
# 269

# %% [markdown]
# ### functions

# %%
def get_prime_and_means(datapath, datetime, zi, varnames=['theta','w'], z_zi_target=0.5, sims=["LES","vles","mynn","ysu","sh"], verbose=False):
    
    datetime_str = "{0:%Y-%m-%d_%H:%M}".format(datetime)
    
    xy_primes    = {}
    xy_means     = {}        

    for sim in sims:        

        xy_primes[sim] = {}
        xy_means[sim]  = {}
        if sim.lower()=="les":
            xy_primes[sim+"_raw"] = {}
            xy_means[sim+"_raw"]  = {}          

        sim_prefix      = sim+"_25m" if sim.lower()=="les" else sim
        fpath           = os.path.join(datapath,"WRF_{0}_3D_{1}_plus_filtered.nc".format(sim_prefix,datetime_str))    
        data            = xarray.open_dataset(fpath)

        if 'ws' in varnames:
            data["ws_filt"] = np.sqrt(data["u_filt"]**2+data["v_filt"]**2)
            data["ws"]      = np.sqrt(data["u"]**2+data["v"]**2)    
                
        z         = data['z'].copy()
        zmean     = np.median(z.values,axis=(1,2))
        z_zi      = zmean/zi    
        k         = np.argmin(np.abs(z_zi-z_zi_target))    
        
        if verbose:
            print("................")            
            print("Simulation : {0}".format(sim))
            print("File : {0}".format(os.path.split(fpath)[-1]))
            print("Vertical level : {0}".format(k))         
        
        for varname in varnames:                
            variable  = data[varname+"_filt"].copy()
            xy_mean   = np.mean(variable.values,axis=(1,2))
            xy_prime  = variable.values - xy_mean[:,np.newaxis,np.newaxis]

            xy_primes[sim][varname] = xy_prime[k,...].copy()
            xy_means[sim][varname]  = xy_mean.copy()

            if verbose:
                print("Getting {0}".format(varname+"_filt"))

            # sim == "LES" also get the raw values, i.e. without the primes
            if sim.lower()=="les":              
                if verbose:            
                    print("Getting {0}".format(varname))        
                variable              = data[varname].copy()
                xy_mean               = np.mean(variable.values,axis=(1,2))
                xy_prime              = variable.values - xy_mean[:,np.newaxis,np.newaxis]
                xy_primes[sim+"_raw"][varname] = xy_prime[k,...].copy()    
                xy_means[sim+"_raw"][varname]  = xy_mean.copy()

    return xy_primes, xy_means

# %% [markdown]
# ### bulk

# %%
plot_cartesian_csd = False
plot_polar_csd     = False
plot_azimuthal_csd = False
save               = True

varnames = ['w','theta']
varname = "w_theta"

year    = 2015
month   = 3
days    = [20,21,28,29,30]
hours   = np.arange(14,24,1)
minutes = np.arange(0,60,10)

for day in days:
    for hour in hours:
        for minute in minutes:

            datetime     = pd.Timestamp(year=year,month=month,day=day,hour=hour,minute=minute)        

            if datetime not in convective_list:
                print ("Skipping {0:%Y-%m-%d_%H-%M}".format(datetime))
                continue
            else:
                print("{0:%Y-%m-%d_%H-%M}".format(datetime))

            zi           = df_zi.loc[datetime].values[0]

            xy_primes, xy_means = get_prime_and_means(datapath, datetime, zi, verbose=True)
            #xy_primes_coarse = {}
            xy_primes_fine = {}
            for sim in xy_primes.keys():
                xy_primes_fine[sim]    = f.make_finer(xy_primes[sim])    

            f1d    = {}
            f2d    = {}
            cs_2d  = {}
            csd_2d = {}

            # power and power density in cartesian grid
            for key in xy_primes_fine.keys():
                print("................")    
                print("Simulation : {0}".format(key))

                arrays  = xy_primes_fine
                if arrays is xy_primes_fine:
                    spacing = 25.0 
                elif arrays is xy_primes_coarse:
                    spacing = 333.0
                else:
                    spacing = spacings[key]
                print("Spacing : {0}".format(spacing))

                f1d[key], f2d[key], cs_2d[key] = f.get_csd_2d(array1=arrays[key][varnames[0]], array2=arrays[key][varnames[1]], spacing=spacing)

                df                             = np.unique(np.diff(f1d[key]))[0]    
                csd_2d[key]                    = cs_2d[key]/np.abs(df)    

            if plot_cartesian_csd:
                for key in xy_primes_fine.keys():
                    print(key)    
                    fig = f.plot_psd_cartesian(f1d[key],np.abs(cs_2d[key]),log10=True)

            # power and power density in polar grid
            x         = {}
            y         = {}
            theta     = {}
            r         = {}
            csd_polar = {}
            cs_polar  = {}

            for key in csd_2d.keys():
                min_radius = 50.0                 
                x[key], y[key], theta[key], r[key], csd_polar[key] = f.psd_cartesian_to_polar(f1d[key],csd_2d[key],thetas=np.arange(135,315.1,0.5), min_radius=min_radius) 
                x[key], y[key], theta[key], r[key], cs_polar[key]  = f.psd_cartesian_to_polar(f1d[key],cs_2d[key], thetas=np.arange(135,315.1,0.5), min_radius=min_radius)         

            if plot_polar_csd:
                for key in xy_primes_fine.keys():
                    print(key)    
                    fig = f.plot_psd_polar(theta[key],r[key],np.abs(cs_polar[key]),log10=True)#,vmin=-5,vmax=7)        

            # power and power density averaged azimuthally
            r_1d   = {}    
            csd_1d = {}
            cs_1d  = {}

            for key in csd_2d.keys():
                csd_1d[key]   = np.nanmean(csd_polar[key],1)
                cs_1d[key]    = np.nanmean(cs_polar[key],1)
                r_1d[key]     = np.nanmean(r[key],1)    

            if plot_azimuthal_csd:

                fig = plt.figure(figsize=(6,6))
                ax  = fig.add_subplot(111)
                ax.grid(color='gray', linestyle=':', linewidth=1)

                for key in keys_in_order:
                    ax.semilogx(r_1d[key],cs_1d[key],lw=3,label=key.upper(),color=colors[key], linestyle=lss[key], linewidth=lws[key])

                ax.set_xlabel("Wave number $\kappa=\sqrt{\kappa_x^2+\kappa_y^2}$ [1/m]")
                ax.set_ylabel("Azimuthally averaged, two-dimensional\nCospectrum [m$^2$/s$^2$]")
                ax.set_title("$z/z_i={0}$".format(z_zi_target)+"\n$t=${0:%Y-%m-%d %H:%M} UTC".format(datetime)+"\nvariable: {0}".format(varname))
                plt.legend()

            if save:
                # save everything for this time THIS WONT WORK IF ALL SIMS ARE NOT ON THE SAME GRID, NOT CODED ROBUSTLY ENOUGH
                fout = os.path.join(outpath,"csd_cartesian_{0:%Y-%m-%d_%H-%M}_{1}.npz".format(datetime,varname))
                print("===> {0}".format(fout))
                np.savez_compressed(fout, f_1d=f1d[key], f_2d=f2d[key], mynn=csd_2d['mynn'], ysu=csd_2d['ysu'], vles=csd_2d['vles'], sh=csd_2d['sh'], les=csd_2d['LES'], les_raw=csd_2d['LES_raw'])

                fout = os.path.join(outpath,"cs_cartesian_{0:%Y-%m-%d_%H-%M}_{1}.npz".format(datetime,varname))
                print("===> {0}".format(fout))
                np.savez_compressed(fout, f_1d=f1d[key], f_2d=f2d[key], mynn=cs_2d['mynn'], ysu=cs_2d['ysu'], vles=cs_2d['vles'], sh=cs_2d['sh'], les=cs_2d['LES'], les_raw=cs_2d['LES_raw'])        

                fout = os.path.join(outpath,"csd_polar_{0:%Y-%m-%d_%H-%M}_{1}.npz".format(datetime,varname))
                print("===> {0}".format(fout))   
                np.savez_compressed(fout, radii=r[key], thetas=theta[key], x=x[key], y=y[key], mynn=csd_polar['mynn'], ysu=csd_polar['ysu'], vles=csd_polar['vles'], sh=csd_polar['sh'], les=csd_polar['LES'], les_raw=csd_polar['LES_raw'])

                fout = os.path.join(outpath,"cs_polar_{0:%Y-%m-%d_%H-%M}_{1}.npz".format(datetime,varname))
                print("===> {0}".format(fout))   
                np.savez_compressed(fout, radii=r[key], thetas=theta[key], x=x[key], y=y[key], mynn=cs_polar['mynn'], ysu=cs_polar['ysu'], vles=cs_polar['vles'], sh=cs_polar['sh'], les=cs_polar['LES'], les_raw=cs_polar['LES_raw'])        

                df = pd.DataFrame(index=r_1d[key],columns=r_1d.keys())
                for key in df.columns:
                    df[key] = csd_1d[key].copy()
                df.columns = [a.lower() for a in df.columns]    
                fout = os.path.join(outpath,"csd_azimuthal_mean_{0:%Y-%m-%d_%H-%M}_{1}.npz".format(datetime,varname))
# ................
# Simulation : LES
# File : WRF_LES_25m_3D_2015-03-30_22:00_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting theta
# Getting w_filt
# Getting w
# ................
# Simulation : vles
# File : WRF_vles_3D_2015-03-30_22:00_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : mynn
# File : WRF_mynn_3D_2015-03-30_22:00_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : ysu
# File : WRF_ysu_3D_2015-03-30_22:00_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : sh
# File : WRF_sh_3D_2015-03-30_22:00_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : LES
# Spacing : 25.0
# ................
# Simulation : LES_raw
# Spacing : 25.0
# ................
# Simulation : vles
# Spacing : 25.0
# ................
# Simulation : mynn
# Spacing : 25.0
# ................
# Simulation : ysu
# Spacing : 25.0
# ................
# Simulation : sh
# Spacing : 25.0
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_cartesian_2015-03-30_22-00_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_cartesian_2015-03-30_22-00_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_polar_2015-03-30_22-00_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_polar_2015-03-30_22-00_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_azimuthal_mean_2015-03-30_22-00_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_azimuthal_mean_2015-03-30_22-00_w_theta.npz
# 2015-03-30_22-10
# ................
# Simulation : LES
# File : WRF_LES_25m_3D_2015-03-30_22:10_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting theta
# Getting w_filt
# Getting w
# ................
# Simulation : vles
# File : WRF_vles_3D_2015-03-30_22:10_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : mynn
# File : WRF_mynn_3D_2015-03-30_22:10_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : ysu
# File : WRF_ysu_3D_2015-03-30_22:10_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : sh
# File : WRF_sh_3D_2015-03-30_22:10_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : LES
# Spacing : 25.0
# ................
# Simulation : LES_raw
# Spacing : 25.0
# ................
# Simulation : vles
# Spacing : 25.0
# ................
# Simulation : mynn
# Spacing : 25.0
# ................
# Simulation : ysu
# Spacing : 25.0
# ................
# Simulation : sh
# Spacing : 25.0
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_cartesian_2015-03-30_22-10_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_cartesian_2015-03-30_22-10_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_polar_2015-03-30_22-10_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_polar_2015-03-30_22-10_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_azimuthal_mean_2015-03-30_22-10_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_azimuthal_mean_2015-03-30_22-10_w_theta.npz
# 2015-03-30_22-20
# ................
# Simulation : LES
# File : WRF_LES_25m_3D_2015-03-30_22:20_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting theta
# Getting w_filt
# Getting w
# ................
# Simulation : vles
# File : WRF_vles_3D_2015-03-30_22:20_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : mynn
# File : WRF_mynn_3D_2015-03-30_22:20_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : ysu
# File : WRF_ysu_3D_2015-03-30_22:20_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : sh
# File : WRF_sh_3D_2015-03-30_22:20_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : LES
# Spacing : 25.0
# ................
# Simulation : LES_raw
# Spacing : 25.0
# ................
# Simulation : vles
# Spacing : 25.0
# ................
# Simulation : mynn
# Spacing : 25.0
# ................
# Simulation : ysu
# Spacing : 25.0
# ................
# Simulation : sh
# Spacing : 25.0
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_cartesian_2015-03-30_22-20_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_cartesian_2015-03-30_22-20_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_polar_2015-03-30_22-20_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_polar_2015-03-30_22-20_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_azimuthal_mean_2015-03-30_22-20_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_azimuthal_mean_2015-03-30_22-20_w_theta.npz
# 2015-03-30_22-30
# ................
# Simulation : LES
# File : WRF_LES_25m_3D_2015-03-30_22:30_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting theta
# Getting w_filt
# Getting w
# ................
# Simulation : vles
# File : WRF_vles_3D_2015-03-30_22:30_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : mynn
# File : WRF_mynn_3D_2015-03-30_22:30_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : ysu
# File : WRF_ysu_3D_2015-03-30_22:30_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : sh
# File : WRF_sh_3D_2015-03-30_22:30_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : LES
# Spacing : 25.0
# ................
# Simulation : LES_raw
# Spacing : 25.0
# ................
# Simulation : vles
# Spacing : 25.0
# ................
# Simulation : mynn
# Spacing : 25.0
# ................
# Simulation : ysu
# Spacing : 25.0
# ................
# Simulation : sh
# Spacing : 25.0
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_cartesian_2015-03-30_22-30_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_cartesian_2015-03-30_22-30_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_polar_2015-03-30_22-30_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_polar_2015-03-30_22-30_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_azimuthal_mean_2015-03-30_22-30_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_azimuthal_mean_2015-03-30_22-30_w_theta.npz
# 2015-03-30_22-40
# ................
# Simulation : LES
# File : WRF_LES_25m_3D_2015-03-30_22:40_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting theta
# Getting w_filt
# Getting w
# ................
# Simulation : vles
# File : WRF_vles_3D_2015-03-30_22:40_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : mynn
# File : WRF_mynn_3D_2015-03-30_22:40_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : ysu
# File : WRF_ysu_3D_2015-03-30_22:40_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : sh
# File : WRF_sh_3D_2015-03-30_22:40_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : LES
# Spacing : 25.0
# ................
# Simulation : LES_raw
# Spacing : 25.0
# ................
# Simulation : vles
# Spacing : 25.0
# ................
# Simulation : mynn
# Spacing : 25.0
# ................
# Simulation : ysu
# Spacing : 25.0
# ................
# Simulation : sh
# Spacing : 25.0
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_cartesian_2015-03-30_22-40_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_cartesian_2015-03-30_22-40_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_polar_2015-03-30_22-40_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_polar_2015-03-30_22-40_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_azimuthal_mean_2015-03-30_22-40_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_azimuthal_mean_2015-03-30_22-40_w_theta.npz
# 2015-03-30_22-50
# ................
# Simulation : LES
# File : WRF_LES_25m_3D_2015-03-30_22:50_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting theta
# Getting w_filt
# Getting w
# ................
# Simulation : vles
# File : WRF_vles_3D_2015-03-30_22:50_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : mynn
# File : WRF_mynn_3D_2015-03-30_22:50_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : ysu
# File : WRF_ysu_3D_2015-03-30_22:50_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : sh
# File : WRF_sh_3D_2015-03-30_22:50_plus_filtered.nc
# Vertical level : 1
# Getting theta_filt
# Getting w_filt
# ................
# Simulation : LES
# Spacing : 25.0
# ................
# Simulation : LES_raw
# Spacing : 25.0
# ................
# Simulation : vles
# Spacing : 25.0
# ................
# Simulation : mynn
# Spacing : 25.0
# ................
# Simulation : ysu
# Spacing : 25.0
# ................
# Simulation : sh
# Spacing : 25.0
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_cartesian_2015-03-30_22-50_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_cartesian_2015-03-30_22-50_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_polar_2015-03-30_22-50_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_polar_2015-03-30_22-50_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/csd_azimuthal_mean_2015-03-30_22-50_w_theta.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/cs_azimuthal_mean_2015-03-30_22-50_w_theta.npz
# Skipping 2015-03-30_23-00
# Skipping 2015-03-30_23-10
# Skipping 2015-03-30_23-20
# Skipping 2015-03-30_23-30
# Skipping 2015-03-30_23-40
# Skipping 2015-03-30_23-50

# %% [raw]
# File : WRF_sh_3D_2015-03-28_15:10_plus_filtered.nc

# %%
minf    = 1/30000.
maxf    = 1/333.
filterf = 1/(333.*5)

# %%
factors = [5, 10, 20, 50, 90]
xlabels = ["${0}\Delta_{{gz}}$".format(a) for a in factors]
xticks  = [1/(333*a) for a in factors]

# %%
fig = plt.figure(figsize=(6,6))
ax  = fig.add_subplot(111)
ax.grid(color='gray', linestyle=':', linewidth=1)

for key in keys_in_order:
    ax.semilogx(r_1d[key],cs_1d[key],lw=3,label=key.upper(),color=colors[key], linestyle=lss[key], linewidth=lws[key])

ax.set_xlabel("Wave number $\kappa=\sqrt{\kappa_x^2+\kappa_y^2}$ [1/m]")
ax.set_ylabel("Azimuthally averaged, two-dimensional\nCospectrum [m$^2$/s$^2$]")
ax.set_title("$z/z_i={0}$".format(z_zi_target)+"\n$t=${0:%Y-%m-%d %H:%M} UTC".format(datetime)+"\nvariable: {0}".format(varname))

ax.set_xlim([minf,filterf])
ax.set_xticks(xticks)
ax.set_xticklabels(xlabels)



plt.legend()
# Out:
# /Users/pdoubraw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Saw kwargs ['lw', 'linewidth'] which are all aliases for 'linewidth'.  Kept value from 'linewidth'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   import sys

# %%
minf    = 1/30000.
maxf    = 1/333.
filterf = 1/(333.*5)

# %%
            fig = plt.figure(figsize=(6,6))
            ax  = fig.add_subplot(111)
            ax.grid(color='gray', linestyle=':', linewidth=1)

            for key in keys_in_order:
                ax.semilogx(r_1d[key],csd_1d[key],lw=3,label=key.upper(),color=colors[key], linestyle=lss[key], linewidth=lws[key])

            ax.set_xlabel("Wave number $\kappa=\sqrt{\kappa_x^2+\kappa_y^2}$ [1/m]")
            ax.set_ylabel("Azimuthally averaged, two-dimensional\nCospectrum [m$^2$/s$^2$]")
            ax.set_title("$z/z_i={0}$".format(z_zi_target)+"\n$t=${0:%Y-%m-%d %H:%M} UTC".format(datetime)+"\nvariable: {0}".format("$<U'w'>$"))
            ax.set_xlim([minf,filterf])
            plt.legend()
# Out:
# /Users/pdoubraw/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Saw kwargs ['lw', 'linewidth'] which are all aliases for 'linewidth'.  Kept value from 'linewidth'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.

# %% [markdown]
# # open saved files to make sure they are ok

# %%
year     = 2015
month    = 3
day      = 20
hour     = 14
minute   = 0
varname  = 'w'
datetime = pd.Timestamp(year=year,month=month,day=day,hour=hour,minute=minute)
    
# save everything for this time THIS WONT WORK IF ALL SIMS ARE NOT ON THE SAME GRID, NOT ROBUST ENOUGH
fout = os.path.join(outpath,"psd_cartesian_{0:%Y-%m-%d_%H-%M}_{1}.npz".format(datetime,varname))
print("===> {0}".format(fout))
cartesian = np.load(fout)

fout = os.path.join(outpath,"psd_polar_{0:%Y-%m-%d_%H-%M}_{1}.npz".format(datetime,varname))
print("===> {0}".format(fout))   
polar = np.load(fout)

fout = os.path.join(outpath,"psd_azimuthal_mean_{0:%Y-%m-%d_%H-%M}_{1}.npz".format(datetime,varname))
print("===> {0}".format(fout))       
df = pd.read_csv(fout, index_col=[0])
# Out:
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/psd_cartesian_2015-03-20_14-00_w.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/psd_polar_2015-03-20_14-00_w.npz
# ===> /Volumes/Baby-Orange/XPIA-NCAR/processed/psd_azimuthal_mean_2015-03-20_14-00_w.npz

# %%
for col in df.columns:
    plt.loglog(df.index, df[col])

# %% [markdown]
# ### figures (optional)

# %% [markdown]
# #### ==> flow field contours

# %%
keys_in_order = ["LES_raw","LES","vles","mynn","ysu","sh"]
varname = 'ws'

# %%
fig = plt.figure(figsize=(6*5,5))
axs = {}

for iax,sim in enumerate(keys_in_order):
    axs[iax] = fig.add_subplot(1,6,iax+1,aspect="equal")
    
    p = axs[iax].contourf(xy_primes_coarse[sim][varname])#, levels=np.arange(-4,4.1,0.2), cmap='magma')
    #variance = np.var(arrays[sim])
    #axs[iax].set_title(sim+"\n $variance={0:.3f}$ m$^2$/s$^2$".format(variance))
    #plt.colorbar(p)
    
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.82, 0.255, 0.02, 0.49])
clb = fig.colorbar(p, cax=cbar_ax, format=FormatStrFormatter('%3.1f'))
clb.set_label('$w\prime$ [cm/s]', labelpad=15, y=0.45)
clb.ax.tick_params(direction='in')
